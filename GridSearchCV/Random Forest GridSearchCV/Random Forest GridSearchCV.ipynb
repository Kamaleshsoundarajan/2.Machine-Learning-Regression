# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#Converting the categorical data into Numerical Data
#Eliminating the dummies from the columns

dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
#list the name of the columns

dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#input split

independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
#output split

dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#Model creation
#Importing GridSearchCV for tuning the hyperparameters 

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','absolute_error'],
'max_features': ['auto','sqrt','log2'],
'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

## fitting the model for grid search

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 20 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.82135837 0.8339844  0.81233314 0.8342074
#         nan        nan 0.82225887 0.83128704 0.81032602 0.83386953]
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
#creating a variable named result and storing the results obtained

result=grid.cv_results_

# %%
#Displaying the best parameters 

print("Best Parameters{}:".format(grid.best_params_))
# Out:
# Best Parameters{'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}:

# %%
#Best Score

print("Best Score: {}".format(grid.best_score_))
# Out:
# Best Score: 0.8342074035329141

# %%
#Constructing a DataFrame using the dictionary 

table=pd.DataFrame.from_dict(result)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002001      0.000851         0.000000        0.000000
# 1        0.001225      0.000343         0.000000        0.000000
# 2        0.047321      0.002414         0.005637        0.000483
# 3        0.396061      0.008140         0.016980        0.001801
# 4        0.048811      0.009349         0.004669        0.000954
# 5        0.331673      0.019390         0.013711        0.000865
# 6        0.001660      0.000497         0.000000        0.000000
# 7        0.001325      0.000227         0.000000        0.000000
# 8        0.140136      0.011373         0.005885        0.001215
# 9        1.358495      0.073984         0.013778        0.001470
# 10       0.145075      0.021802         0.003946        0.000519
# 11       1.253883      0.064985         0.011018        0.002000
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute_error               auto                 10
# 7   absolute_error               auto                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.853361
# 3   {'criterion': 'squared_error', 'max_features':...           0.859354
# 4   {'criterion': 'squared_error', 'max_features':...           0.847168
# 5   {'criterion': 'squared_error', 'max_features':...           0.858565
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.858717
# 9   {'criterion': 'absolute_error', 'max_features'...           0.854483
# 10  {'criterion': 'absolute_error', 'max_features'...           0.832206
# 11  {'criterion': 'absolute_error', 'max_features'...           0.855900
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.757599           0.850725           0.813489
# 3            0.778212           0.862060           0.827497
# 4            0.755298           0.825312           0.810917
# 5            0.783260           0.858404           0.829928
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.767584           0.822044           0.819626
# 9            0.780245           0.856282           0.826396
# 10           0.762085           0.840255           0.813075
# 11           0.780030           0.857780           0.829321
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                9
# 1                 NaN              NaN             NaN                9
# 2            0.831617         0.821358        0.034983                6
# 3            0.842800         0.833984        0.030536                2
# 4            0.822971         0.812333        0.030822                7
# 5            0.840880         0.834207        0.027703                1
# 6                 NaN              NaN             NaN                9
# 7                 NaN              NaN             NaN                9
# 8            0.843324         0.822259        0.030885                5
# 9            0.839029         0.831287        0.027756                4
# 10           0.804009         0.810326        0.027383                8
# 11           0.846317         0.833870        0.028745                3

# %%
#Get the inputs from the user for prediction

Age_input=int(input("Age:"))
BMI_input=float(input("BMI:"))
Children_input=float(input("Children:"))
Sex_male_input=float(input("Male 1 or 0:"))
Smoker_input=float(input("Smoker 1 or 0:"))
# Out:
# Age: 30
# BMI: 34.098
# Children: 4
# Male 1 or 0: 1
# Smoker 1 or 0: 1

# %%
#Performing Future prediction

Future_prediction=grid.predict([[Age_input,BMI_input,Children_input,Sex_male_input,Smoker_input]])
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[37019.4011735]
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
